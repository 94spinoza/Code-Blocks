# %% [markdown]
# <a href="https://colab.research.google.com/github/94spinoza/Code-Blocks/blob/main/Matplotlib_%26_Seaborn_%ED%95%9C%EA%B8%80%ED%91%9C%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# 해당 글은 Colab에서 작업하는 것을 기준으로 만들었다.
#
# 대부분 프로그램들이 영어를 기준으로 만들어졌다.
#
# 그래서 한글을 출력할 때 오류가 일어나는 경우가 있다.
#
# 특히 그래프를 그려야할 때 한글이 깨지면 매우 곤란하다.
#
# 아래 코드를 활용하면 Matplotlib과 Seaborn에서의 한글깨짐을 고칠 수 있다.
#
# **\* 코드 블록**
#
# ```
# # 글꼴 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
#
# # 글꼴 설정
# import matplotlib.pyplot as plt
#
# plt.rc('font', family='NanumBarunGothic')
# ```
#
# 모두 행복하길
#
# \-끝-
